# %%
import pandas as pd
from sqlalchemy import create_engine, func

# %%
plan_csv = r"C:\Users\rmwc_\OneDrive\Documents\Bootcamp\Project3\plan-attributes-puf.csv"

# %%
# Read csv into panda dataframe
plan_df = pd.read_csv(plan_csv)
print(plan_df.head())
# Out:
#    BusinessYear StateCode  IssuerId IssuerMarketPlaceMarketingName SourceName  \
# 0          2025        AK     21989         Delta Dental of Alaska       HIOS
# 1          2025        AK     21989         Delta Dental of Alaska       HIOS
# 2          2025        AK     21989         Delta Dental of Alaska       HIOS
# 3          2025        AK     21989         Delta Dental of Alaska       HIOS
# 4          2025        AK     21989         Delta Dental of Alaska       HIOS
#
#             ImportDate      MarketCoverage DentalOnlyPlan StandardComponentId  \
# 0  2024-08-29 01:02:15          Individual            Yes      21989AK0030001
# 1  2024-08-29 01:02:15          Individual            Yes      21989AK0030001
# 2  2024-08-29 01:02:15  SHOP (Small Group)            Yes      21989AK0130004
# 3  2024-08-29 01:02:15  SHOP (Small Group)            Yes      21989AK0080001
# 4  2024-08-29 01:02:15          Individual            Yes      21989AK0050001
#
#                                 PlanMarketingName  ...  \
# 0                       Delta Dental Premier Plan  ...
# 1                       Delta Dental Premier Plan  ...
# 2  Delta Dental Premier, +1000, 100/80/50, 50, PF  ...
# 3        Delta Dental Premier 1000, 100/80/50, 50  ...
# 4                      Delta Dental PPO 1000 Plan  ...
#
#   TEHBDedOutOfNetFamilyPerPerson TEHBDedOutOfNetFamilyPerGroup  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#   TEHBDedCombInnOonIndividual TEHBDedCombInnOonFamilyPerPerson  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
#
#   TEHBDedCombInnOonFamilyPerGroup IsHSAEligible HSAOrHRAEmployerContribution  \
# 0                             NaN           NaN                          NaN
# 1                             NaN           NaN                          NaN
# 2                             NaN           NaN                          NaN
# 3                             NaN           NaN                          NaN
# 4                             NaN           NaN                          NaN
#
#   HSAOrHRAEmployerContributionAmount URLForSummaryofBenefitsCoverage  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#                                         PlanBrochure
# 0  https://www.deltadentalak.com/-/media/deltaden...
# 1  https://www.deltadentalak.com/-/media/deltaden...
# 2                                                NaN
# 3                                                NaN
# 4  https://www.deltadentalak.com/-/media/deltaden...
#
# [5 rows x 151 columns]
# C:\Users\rmwc_\AppData\Local\Temp\ipykernel_132496\4102378068.py:2: DtypeWarning: Columns (64,80,81,82,86,87,88,89,90,91,147,148) have mixed types. Specify dtype option on import or set low_memory=False.
#   plan_df = pd.read_csv(plan_csv)

# %%
# Create a Dataframe for issuers
clean_plan_df = pd.DataFrame({
    "PlanID": plan_df["PlanId"],
    "StateCode": plan_df["StateCode"],
    "IssuerID": plan_df["IssuerId"],
    "MarketCoverage": plan_df["MarketCoverage"],
    "DentalOnlyPlan": plan_df["DentalOnlyPlan"],
    "StandardComponentId": plan_df["StandardComponentId"],
    "PlanMarketingName": plan_df["PlanMarketingName"],
    "HIOSProductId": plan_df["HIOSProductId"],
    "NetworkId": plan_df["NetworkId"],
    "ServiceAreaId": plan_df["ServiceAreaId"],
    "PlanType": plan_df["PlanType"],
    "MetalLevel": plan_df["MetalLevel"],
    "QHPNonQHPTypeId": plan_df["QHPNonQHPTypeId"],
    "WellnessProgramOffered": plan_df["WellnessProgramOffered"],
    "DiseaseManagementProgramsOffered": plan_df["DiseaseManagementProgramsOffered"],
    "EHBPercentTotalPremium": plan_df["EHBPercentTotalPremium"],
    "OutOfServiceAreaCoverage": plan_df["OutOfServiceAreaCoverage"],
    "OutOfServiceAreaCoverageDescription": plan_df["OutOfServiceAreaCoverageDescription"],
    "PlanVariantMarketingName": plan_df["PlanVariantMarketingName"],
    "CSRVariationType": plan_df["CSRVariationType"],
    "MedicalDrugDeductiblesIntegrated": plan_df["MedicalDrugDeductiblesIntegrated"],
    "MedicalDrugMaximumOutofPocketIntegrated": plan_df["MedicalDrugMaximumOutofPocketIntegrated"],
    "PlanBrochure": plan_df["PlanBrochure"],
})

clean_plan_df.head()
# Out:
#               PlanID StateCode  IssuerID      MarketCoverage DentalOnlyPlan  \
# 0  21989AK0030001-00        AK     21989          Individual            Yes
# 1  21989AK0030001-01        AK     21989          Individual            Yes
# 2  21989AK0130004-00        AK     21989  SHOP (Small Group)            Yes
# 3  21989AK0080001-00        AK     21989  SHOP (Small Group)            Yes
# 4  21989AK0050001-00        AK     21989          Individual            Yes
#
#   StandardComponentId                               PlanMarketingName  \
# 0      21989AK0030001                       Delta Dental Premier Plan
# 1      21989AK0030001                       Delta Dental Premier Plan
# 2      21989AK0130004  Delta Dental Premier, +1000, 100/80/50, 50, PF
# 3      21989AK0080001        Delta Dental Premier 1000, 100/80/50, 50
# 4      21989AK0050001                      Delta Dental PPO 1000 Plan
#
#   HIOSProductId NetworkId ServiceAreaId  ... WellnessProgramOffered  \
# 0    21989AK003    AKN003        AKS003  ...                    NaN
# 1    21989AK003    AKN003        AKS003  ...                    NaN
# 2    21989AK013    AKN001        AKS001  ...                    NaN
# 3    21989AK008    AKN001        AKS001  ...                    NaN
# 4    21989AK005    AKN004        AKS004  ...                    NaN
#
#   DiseaseManagementProgramsOffered EHBPercentTotalPremium  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
#
#   OutOfServiceAreaCoverage  OutOfServiceAreaCoverageDescription  \
# 0                      Yes  Non-participating provider benefits
# 1                      Yes  Non-participating provider benefits
# 2                      Yes                     National Network
# 3                      Yes                     National Network
# 4                      Yes              Out-of-network benefits
#
#                          PlanVariantMarketingName  \
# 0                       Delta Dental Premier Plan
# 1                       Delta Dental Premier Plan
# 2  Delta Dental Premier, +1000, 100/80/50, 50, PF
# 3        Delta Dental Premier 1000, 100/80/50, 50
# 4                      Delta Dental PPO 1000 Plan
#
#                   CSRVariationType MedicalDrugDeductiblesIntegrated  \
# 0   Standard Low Off Exchange Plan                              NaN
# 1    Standard Low On Exchange Plan                              NaN
# 2  Standard High Off Exchange Plan                              NaN
# 3  Standard High Off Exchange Plan                              NaN
# 4  Standard High Off Exchange Plan                              NaN
#
#   MedicalDrugMaximumOutofPocketIntegrated  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                         PlanBrochure
# 0  https://www.deltadentalak.com/-/media/deltaden...
# 1  https://www.deltadentalak.com/-/media/deltaden...
# 2                                                NaN
# 3                                                NaN
# 4  https://www.deltadentalak.com/-/media/deltaden...
#
# [5 rows x 23 columns]

# %%
# Filter Dataframe to not include dental only plans or plans where market coverage = shop
filtered_plan_df = clean_plan_df[
    (clean_plan_df["MarketCoverage"] != "SHOP") &
    (clean_plan_df["DentalOnlyPlan"] != "Yes")
]

filtered_plan_df.head()
# Out:
#                PlanID StateCode  IssuerID MarketCoverage DentalOnlyPlan  \
# 29  38344AK1060001-01        AK     38344     Individual             No
# 30  38344AK1060001-02        AK     38344     Individual             No
# 31  38344AK1060001-03        AK     38344     Individual             No
# 32  38344AK1060002-01        AK     38344     Individual             No
# 33  38344AK1060002-02        AK     38344     Individual             No
#
#    StandardComponentId                         PlanMarketingName  \
# 29      38344AK1060001    Premera Blue Cross Preferred Gold 1500
# 30      38344AK1060001    Premera Blue Cross Preferred Gold 1500
# 31      38344AK1060001    Premera Blue Cross Preferred Gold 1500
# 32      38344AK1060002  Premera Blue Cross Preferred Silver 4500
# 33      38344AK1060002  Premera Blue Cross Preferred Silver 4500
#
#    HIOSProductId NetworkId ServiceAreaId  ... WellnessProgramOffered  \
# 29    38344AK106    AKN002        AKS001  ...                     No
# 30    38344AK106    AKN002        AKS001  ...                     No
# 31    38344AK106    AKN002        AKS001  ...                     No
# 32    38344AK106    AKN002        AKS001  ...                     No
# 33    38344AK106    AKN002        AKS001  ...                     No
#
#    DiseaseManagementProgramsOffered EHBPercentTotalPremium  \
# 29  Asthma, Heart Disease, Diabetes                 0.9928
# 30  Asthma, Heart Disease, Diabetes                 0.9928
# 31  Asthma, Heart Disease, Diabetes                 0.9928
# 32  Asthma, Heart Disease, Diabetes                 0.9937
# 33  Asthma, Heart Disease, Diabetes                 0.9937
#
#    OutOfServiceAreaCoverage  \
# 29                      Yes
# 30                      Yes
# 31                      Yes
# 32                      Yes
# 33                      Yes
#
#                   OutOfServiceAreaCoverageDescription  \
# 29  If you're outside Alaska and Washington (the s...
# 30  If you're outside Alaska and Washington (the s...
# 31  If you're outside Alaska and Washington (the s...
# 32  If you're outside Alaska and Washington (the s...
# 33  If you're outside Alaska and Washington (the s...
#
#                     PlanVariantMarketingName  \
# 29    Premera Blue Cross Preferred Gold 1500
# 30    Premera Blue Cross Preferred Gold 1500
# 31    Premera Blue Cross Preferred Gold 1500
# 32  Premera Blue Cross Preferred Silver 4500
# 33  Premera Blue Cross Preferred Silver 4500
#
#                        CSRVariationType MedicalDrugDeductiblesIntegrated  \
# 29       Standard Gold On Exchange Plan                              Yes
# 30     Zero Cost Sharing Plan Variation                              Yes
# 31  Limited Cost Sharing Plan Variation                              Yes
# 32     Standard Silver On Exchange Plan                              Yes
# 33     Zero Cost Sharing Plan Variation                              Yes
#
#    MedicalDrugMaximumOutofPocketIntegrated  \
# 29                                     Yes
# 30                                     Yes
# 31                                     Yes
# 32                                     Yes
# 33                                     Yes
#
#                                          PlanBrochure
# 29  https://www.premera.com/documents/031112_2025.pdf
# 30  https://www.premera.com/documents/031040_2025.pdf
# 31  https://www.premera.com/documents/031040_2025.pdf
# 32  https://www.premera.com/documents/031112_2025.pdf
# 33  https://www.premera.com/documents/031040_2025.pdf
#
# [5 rows x 23 columns]

# %%
count_plan = len(filtered_plan_df)

print(f"Total record count: {count_plan}")
# Out:
# Total record count: 23027

# %%
# Conntect to PostgreSQL database (need psycopg2-binary - pip install psycopg2-binary)
engine = create_engine("postgresql://postgres:postgres@localhost:5432/HealthCareValue_DB")

# %%
# Append dataframe to Rates table in HealthCareValues_DB
filtered_plan_df.to_sql("PlanAttributes", engine, if_exists="append", index=False)
# Out:
# 405
